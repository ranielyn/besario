# %% [markdown]
# Exercise 1: Regular Expressions
# Load the Shakespeare’s Hamlet from the NLTK (shakespeare-hamlet.txt)

# %% [markdown]
# Words containing 2 vowels characters

# %%
import re
import nltk
import math
import string

nltk.download('gutenberg')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
hamlet_raw = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt') #raw hamlet

re.findall(r'(?<=\W)[A-Za-z][aeiou]{2}[A-Za-z](?=\W)',hamlet_raw)
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['your',
#  'liue',
#  'your',
#  'Haue',
#  'meet',
#  'Giue',
#  'good',
#  'giue',
#  'good',
#  'haue',
#  'haue',
#  'your',
#  'haue',
#  'dead',
#  'fear',
#  'look',
#  'dead',
#  'Good',
#  'goes',
#  'euen',
#  'Seal',
#  'seiz',
#  'Diet',
#  'head',
#  'good',
#  'haue',
#  'euer',
#  'haue',
#  'haue',
#  'Haue',
#  'haue',
#  'Your',
#  'haue',
#  'haue',
#  'good',
#  'your',
#  'your',
#  'your',
#  'Head',
#  'haue',
#  'Laer',
# ...

# %% [markdown]
# Words that contain a hyphen

# %%
import re
re.findall(r'\w+-\w+[-\w+]*',hamlet_raw)
# Out:
# ['Leige-men',
#  'a-while',
#  'Ship-wrights',
#  'ioynt-Labourer',
#  'post-hast',
#  'vp-hoorded',
#  'shrill-sounding',
#  'Selfe-slaughter',
#  'Bakt-meats',
#  'feare-surprized',
#  'Prison-House',
#  'Quick-siluer',
#  'Lazar-like',
#  'Glow-worme',
#  'out-breake',
#  'a-while',
#  're-hasty',
#  'well-tooke',
#  'Table-booke',
#  'God-a-mercy',
#  'Plum-Tree',
#  'ouer-happy',
#  'out-stretcht',
#  'euer-preserued',
#  'ore-hanging',
#  'be-ratled',
#  'Goose-quils',
#  'North-West',
#  'Pastoricall-Comicall-Historicall-Pastorall',
#  'Tragicall-Historicall',
#  'Tragicall-Comicall-Historicall-Pastorall',
#  're-sized',
#  'a-worke',
#  'Strumpet-Fortune',
#  'bare-foot',
#  'ore-teamed',
#  'muddy-metled',
#  'a-dreames',
#  'a-crosse',
#  'Pigeon-Liuer',
#  'ore-wrought',
#  'Heart-ake',
#  're-deliuer',
#  're-throwne',
#  'Town-Cryer',
#  'Whirle-winde',
#  'Pery-wig-pated',
#  're-doing',
#  'ore-stop',
#  'ouer-done',
#  'ouer-done',
#  'Iouerney-men',
#  'co-mingled',
# ...

# %% [markdown]
# Words in their present progressive form (ends in -ing)

# %%
re.findall(r'(?<=\W)[A-Za-z-]+ing(?=\W)',hamlet_raw)
# Out:
# ['King',
#  'stirring',
#  'thing',
#  'nothing',
#  'Touching',
#  'beating',
#  'King',
#  'King',
#  'something',
#  'King',
#  'King',
#  'King',
#  'thing',
#  'foreknowing',
#  'being',
#  'thing',
#  'shrill-sounding',
#  'warning',
#  'erring',
#  'crowing',
#  'Dawning',
#  'fitting',
#  'morning',
#  'King',
#  'King',
#  'Dropping',
#  'weighing',
#  'Holding',
#  'thinking',
#  'Importing',
#  'meeting',
#  'bearing',
#  'greeting',
#  'Giuing',
#  'King',
#  'King',
#  'nothing',
#  'Asking',
#  'King',
#  'King',
#  'King',
#  'Passing',
#  'King',
#  'mourning',
#  'Vnderstanding',
#  'thing',
#  'vnpreuayling',
#  'going',
#  'King',
#  'louing',
#  'smiling',
#  'Respeaking',
#  'Euerlasting',
#  'King',
#  'louing',
#  'flushing',
#  'Wedding',
#  'King',
#  'King',
#  'King',
#  'thing',
#  'Morning',
#  'vnderstanding',
#  'trifling',
#  'lasting',
#  'yeelding',
#  'saying',
#  'Spring',
#  'blessing',
#  'blessing',
#  'being',
#  'borrowing',
#  'Blessing',
# ...

# %% [markdown]
# Words in their superlative form (ends in -est)

# %%
re.findall(r'(?<=\W)[A-Za-z-]+est(?=\W)',hamlet_raw)
# Out:
# ['honest',
#  'wisest',
#  'best',
#  'deerest',
#  'cheefest',
#  'best',
#  'dearest',
#  'opprest',
#  'chariest',
#  'best',
#  'exprest',
#  'best',
#  'lightest',
#  'best',
#  'Incest',
#  'pursuest',
#  'honest',
#  'request',
#  'sayest',
#  'Rest',
#  'rest',
#  'rest',
#  'rest',
#  'best',
#  'Best',
#  'honest',
#  'Honest',
#  'honest',
#  'honest',
#  'rest',
#  'honest',
#  'lest',
#  'North-West',
#  'best',
#  'honest',
#  'rest',
#  'honest',
#  'honest',
#  'honest',
#  'doest',
#  'rest',
#  'best',
#  'Tempest',
#  'blest',
#  'rest',
#  'brest',
#  'iest',
#  'iest',
#  'Forrest',
#  'rest',
#  'lowest',
#  'highest',
#  'eldest',
#  'possest',
#  'weakest',
#  'strongest',
#  'Test',
#  'blest',
#  'wisest',
#  'best',
#  'blackest',
#  'profoundest',
#  'wisest',
#  'wouldest',
#  'knowest',
#  'rest',
#  'diddest',
#  'Quest',
#  'answerest',
#  'Guest',
#  'Guest',
#  'liest',
#  'lyest',
#  'rest',
#  'Iest',
#  'Priest',
#  'Priest',
#  'rest',
# ...

# %% [markdown]
# Words at the end of the sentence (next to sentence ending punctuations)

# %%
re.findall(r'(?<=[?.!]\W)(?<=\W)[A-Z][a-z-]+(?=\W)',hamlet_raw)
# Out:
# ['Scoena',
#  'Who',
#  'Nay',
#  'Long',
#  'Barnardo',
#  'He',
#  'You',
#  'For',
#  'Haue',
#  'Not',
#  'Well',
#  'If',
#  'Enter',
#  'Stand',
#  'Friends',
#  'And',
#  'Giue',
#  'Barnardo',
#  'Holla',
#  'Say',
#  'Welcome',
#  'What',
#  'Horatio',
#  'Tush',
#  'Sit',
#  'Well',
#  'Last',
#  'Peace',
#  'In',
#  'Thou',
#  'Lookes',
#  'Marke',
#  'Most',
#  'It',
#  'Question',
#  'What',
#  'It',
#  'See',
#  'Stay',
#  'How',
#  'You',
#  'What',
#  'Before',
#  'Is',
#  'As',
#  'Thus',
#  'In',
#  'Good',
#  'That',
#  'In',
#  'Now',
#  'Enter',
#  'Stay',
#  'If',
#  'If',
#  'Or',
#  'Stay',
#  'Stop',
#  'Shall',
#  'Do',
#  'It',
#  'And',
#  'And',
#  'It',
#  'Some',
#  'So',
#  'But',
#  'For',
#  'Let',
#  'Though',
#  'Therefore',
#  'Now',
#  'So',
#  'Enter',
#  'We',
#  'In',
#  'In',
#  'We',
#  'You',
#  'What',
#  'You',
#  'What',
#  'The',
#  'What',
#  'Dread',
#  'Haue',
#  'What',
#  'He',
#  'Take',
#  'How',
#  'Not',
#  'Good',
#  'Do',
# ...

# %% [markdown]
# Tokenize the data using Penn Tree Bank Tokenization

# %%
ptb_tokenizer = nltk.tokenize.treebank.TreebankWordTokenizer()
PTB_TOKENS = ptb_tokenizer.tokenize(hamlet_raw)
PTB_TOKENS[:500]
# Out:
# ['[',
#  'The',
#  'Tragedie',
#  'of',
#  'Hamlet',
#  'by',
#  'William',
#  'Shakespeare',
#  '1599',
#  ']',
#  'Actus',
#  'Primus.',
#  'Scoena',
#  'Prima.',
#  'Enter',
#  'Barnardo',
#  'and',
#  'Francisco',
#  'two',
#  'Centinels.',
#  'Barnardo.',
#  'Who',
#  "'s",
#  'there',
#  '?',
#  'Fran.',
#  'Nay',
#  'answer',
#  'me',
#  ':',
#  'Stand',
#  '&',
#  'vnfold',
#  'your',
#  'selfe',
#  'Bar.',
#  'Long',
#  'liue',
#  'the',
#  'King',
#  'Fran.',
#  'Barnardo',
#  '?',
#  'Bar.',
#  'He',
#  'Fran.',
#  'You',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  'Bar.',
#  "'T",
#  'is',
#  'now',
#  'strook',
#  'twelue',
#  ',',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'Francisco',
#  'Fran.',
#  'For',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  ':',
#  "'T",
#  'is',
#  'bitter',
#  'cold',
#  ',',
#  'And',
#  'I',
#  'am',
#  'sicke',
#  'at',
#  'heart',
#  'Barn.',
#  'Haue',
#  'you',
#  'had',
#  'quiet',
#  'Guard',
# ...

# %% [markdown]
# Apply case folding on the tokens

# %%
CF_PTB_TOKENS = [w.lower() for w in PTB_TOKENS]
CF_PTB_TOKENS[:500]
# Out:
# ['[',
#  'the',
#  'tragedie',
#  'of',
#  'hamlet',
#  'by',
#  'william',
#  'shakespeare',
#  '1599',
#  ']',
#  'actus',
#  'primus.',
#  'scoena',
#  'prima.',
#  'enter',
#  'barnardo',
#  'and',
#  'francisco',
#  'two',
#  'centinels.',
#  'barnardo.',
#  'who',
#  "'s",
#  'there',
#  '?',
#  'fran.',
#  'nay',
#  'answer',
#  'me',
#  ':',
#  'stand',
#  '&',
#  'vnfold',
#  'your',
#  'selfe',
#  'bar.',
#  'long',
#  'liue',
#  'the',
#  'king',
#  'fran.',
#  'barnardo',
#  '?',
#  'bar.',
#  'he',
#  'fran.',
#  'you',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  'bar.',
#  "'t",
#  'is',
#  'now',
#  'strook',
#  'twelue',
#  ',',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'francisco',
#  'fran.',
#  'for',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  ':',
#  "'t",
#  'is',
#  'bitter',
#  'cold',
#  ',',
#  'and',
#  'i',
#  'am',
#  'sicke',
#  'at',
#  'heart',
#  'barn.',
#  'haue',
#  'you',
#  'had',
#  'quiet',
#  'guard',
# ...

# %% [markdown]
# Lemmatize the case folded tokens using Word Net Lemmatizer

# %%
import nltk
nltk.download('wordnet')
lemmatizer = nltk.WordNetLemmatizer()
WNL_PTB_TOKENS = [lemmatizer.lemmatize(w) for w in PTB_TOKENS]
WNL_PTB_TOKENS[:500]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['[',
#  'The',
#  'Tragedie',
#  'of',
#  'Hamlet',
#  'by',
#  'William',
#  'Shakespeare',
#  '1599',
#  ']',
#  'Actus',
#  'Primus.',
#  'Scoena',
#  'Prima.',
#  'Enter',
#  'Barnardo',
#  'and',
#  'Francisco',
#  'two',
#  'Centinels.',
#  'Barnardo.',
#  'Who',
#  "'s",
#  'there',
#  '?',
#  'Fran.',
#  'Nay',
#  'answer',
#  'me',
#  ':',
#  'Stand',
#  '&',
#  'vnfold',
#  'your',
#  'selfe',
#  'Bar.',
#  'Long',
#  'liue',
#  'the',
#  'King',
#  'Fran.',
#  'Barnardo',
#  '?',
#  'Bar.',
#  'He',
#  'Fran.',
#  'You',
#  'come',
#  'most',
#  'carefully',
#  'vpon',
#  'your',
#  'houre',
#  'Bar.',
#  "'T",
#  'is',
#  'now',
#  'strook',
#  'twelue',
#  ',',
#  'get',
#  'thee',
#  'to',
#  'bed',
#  'Francisco',
#  'Fran.',
#  'For',
#  'this',
#  'releefe',
#  'much',
#  'thankes',
#  ':',
#  "'T",
# ...

# %% [markdown]
# b. Word Token (Number of tokens)

# %%
len(WNL_PTB_TOKENS)
# Out:
# 34442
